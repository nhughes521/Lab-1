# %% [markdown]
# ### Precipitation Level on the 1st of each Month in 2017 vs in 2019

# %% [markdown]
# #### Outline

# %% [markdown]
# My idea for the project is to illustrate the difference in precipitation level in inches on the first of each month. I'm hoping to see the difference (if any) between the precipation levels on the first of each month in 2017 versus the precipation levels on the first of each month in 2019.

# %% [markdown]
# ![Graph](https://raw.githubusercontent.com/nhughes521/Lab-1/master/IMG_0617%20(1).jpg)

# %% [markdown]
# #### Conclusion

# %% [markdown]
# My goal for this project was to come up with a graph concept that will successfully illustrate the difference in the precipitation levels on the first of each month in 2017 vs in 2019. After analyzing the data, I was able to conclude that there were significant differences in the precipation levels on the first of each month.
